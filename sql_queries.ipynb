# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.3.4)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (3.10.7)
# Requirement already satisfied: kagglehub in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.3.13)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: duckdb in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: scipy>=1.8.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 4)) (2025.11.12)

# %%
import duckdb
import pandas as pd
import ast

# %%
df = pd.read_csv('data/cleaned_spotify_tracks.csv')

# Convert list-like strings to real lists
df['track_genre'] = df['track_genre'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
df.head()
# Out:
#                  track_id                          artists                                          track_name       track_genre  explicit  popularity  danceability  energy  key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence    tempo  duration_ms  time_signature    primary_artist  duration_sec  duration_min
# 0  0000vdREvCVMxbQTkS888c                         ['Rill']                                               Lolly          [german]         1          44         0.910   0.374    8    -9.844     0       0.1990      0.075700           0.00301    0.1540    0.432  104.042       160725               4              Rill       160.725      2.678750
# 1  000CC8EParg64OmTxVnZ0p                    ['Glee Cast']  It's All Coming Back To Me Now (Glee Cast Version)            [club]         0          47         0.269   0.516    0    -7.361     1       0.0366      0.406000           0.00000    0.1170    0.341  178.174       322933               4         Glee Cast       322.933      5.382217
# 2  000Iz0K615UepwSJ5z2RE5  ['Paul Kalkbrenner', 'Pig&Dan']                       Böxig Leise - Pig & Dan Remix  [minimal-techno]         0          22         0.686   0.560    5   -13.264     0       0.0462      0.001140           0.18100    0.1110    0.108  119.997       515360               4  Paul Kalkbrenner       515.360      8.589333
# 3  000RDCYioLteXcutOjeweY                ['Jordan Sandhu']                                          Teeje Week         [hip-hop]         0          62         0.679   0.770    0    -3.537     1       0.1900      0.058300           0.00000    0.0825    0.839  161.721       190203               4     Jordan Sandhu       190.203      3.170050
# 4  000qpdoc97IMTBvF8gwcpy             ['Paul Kalkbrenner']                                                Tief  [minimal-techno]         0          19         0.519   0.431    6   -13.606     0       0.0291      0.000964           0.72000    0.0916    0.234  129.971       331240               4  Paul Kalkbrenner       331.240      5.520667

# %%
pd.set_option("display.width", 2000)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

# Get the top 20 most popular tracks
result = duckdb.query("""
    SELECT track_name, primary_artist, popularity
    FROM df
    ORDER BY popularity DESC
    LIMIT 20
""").to_df()


print("Top 20 most popular tracks")
print(result)
print("/n")

# Select tracks with danceability greater than 0.9
result = duckdb.query("""
SELECT track_name, primary_artist, danceability
FROM df
WHERE danceability > 0.9
ORDER BY danceability DESC;
""").to_df()

print("Tracks with danceability greater than 0.9")
print(result)
print("/n")

# Select average audio features by genre
result = duckdb.query("""
    SELECT 
        g.genre,
        AVG(danceability) AS avg_dance,
        AVG(energy) AS avg_energy,
        AVG(valence) AS avg_valence,
        AVG(tempo) AS avg_tempo
    FROM df
    CROSS JOIN UNNEST(track_genre) AS g(genre)
    GROUP BY g.genre
    ORDER BY avg_energy DESC
""").to_df()


print("Average audio features by genre")
print(result)
print("/n")

# Get the loudest tracks 
result = duckdb.query("""
SELECT track_name, primary_artist, loudness
FROM df
ORDER BY loudness DESC;
""").to_df()

print("Loudest tracks")
print(result)
print("/n")

# Get the 20 longest tracks
result = duckdb.query("""
SELECT track_name, primary_artist, duration_min, duration_sec
FROM df
ORDER BY duration_min DESC
LIMIT 20;
""").to_df()

print("20 Longest tracks")
print(result)
print("/n")

# Get the 20 shortest tracks
result = duckdb.query("""
SELECT track_name, primary_artist, duration_min, duration_sec
FROM df
ORDER BY duration_min ASC
LIMIT 20;
""").to_df()
print("20 Shortest tracks")
print(result)
print("/n")

# Get tracks with instrumentalness greater than 0.8
result = duckdb.query("""
SELECT track_name, primary_artist, instrumentalness
FROM df
WHERE instrumentalness > 0.8
ORDER BY instrumentalness DESC;
""").to_df()

print("Tracks with instrumentalness greater than 0.8")
print(result)
print("/n")

# Get the average popularity by year
result = duckdb.query("""
SELECT release_year, AVG(popularity) AS avg_popularity
FROM df
GROUP BY release_year
ORDER BY release_year ASC;
""").to_df()

print("Average popularity by year")
print(result)
print("/n")

# Get tracks with speechiness greater than 0.5
result = duckdb.query("""
SELECT track_name, primary_artist, speechiness
FROM df
WHERE speechiness > 0.5
ORDER BY speechiness DESC;
""").to_df()

print("Tracks with speechiness greater than 0.5")
print(result)
print("/n")

# Get the top 10 genres by number of tracks
result = duckdb.query("""
    SELECT g.genre, COUNT(*) AS track_count
    FROM df
    CROSS JOIN UNNEST(track_genre) AS g(genre)
    GROUP BY g.genre
    ORDER BY track_count DESC
    LIMIT 10
""").to_df()

print("Top 10 genres by number of tracks")
print(result)
# Out:
# Top 20 most popular tracks
#                                track_name     primary_artist  popularity
# 0               Unholy (feat. Kim Petras)          Sam Smith         100
# 1   Quevedo: Bzrp Music Sessions, Vol. 52           Bizarrap          99
# 2                         I'm Good (Blue)       David Guetta          98
# 3                              La Bachata      Manuel Turizo          98
# 4                         Me Porto Bonito          Bad Bunny          97
# 5                        Tití Me Preguntó          Bad Bunny          97
# 6                     Under The Influence        Chris Brown          96
# 7                                  Efecto          Bad Bunny          96
# 8                         I Ain't Worried        OneRepublic          96
# 9                               As It Was       Harry Styles          95
# 10                          Ojitos Lindos          Bad Bunny          95
# 11                            Moscow Mule          Bad Bunny          94
# 12                          Glimpse of Us               Joji          94
# 13                           Another Love          Tom Odell          93
# 14                               PROVENZA            KAROL G          93
# 15                               Neverita          Bad Bunny          93
# 16                                CUFF IT            Beyoncé          93
# 17                        Sweater Weather  The Neighbourhood          93
# 18                       I Wanna Be Yours     Arctic Monkeys          92
# 19          Calm Down (with Selena Gomez)               Rema          92
# /n
# Tracks with danceability greater than 0.9
#                                                     track_name     primary_artist  danceability
# 0                                                     Sol Clap            Quantic         0.985
# 1                                                Medicaid Baby  That Girl Lay Lay         0.984
# 2                                                  Inspiration       Delano Smith         0.983
# 3                                               Daily Routines    Oliver Schories         0.982
# 4    Featuring Mixx Master Lee, Red Rum & J. Smoov (Funky Mix)    Mixx Master Lee         0.981
# ..                                                         ...                ...           ...
# 969        Mad Mad World (feat. Sizzla Kalonji & Collie Buddz)             Shaggy         0.901
# 970                                         No Eres Tú, Soy Yo              Brray         0.901
# 971                                                    Hey Mor              Ozuna         0.901
# 972                                          Itsy Bitsy Spider      Toddler Tunes         0.901
# 973                                        Leave The Lights On            Droplex         0.901
#
# [974 rows x 3 columns]
# /n
# Average audio features by genre
#            genre  avg_dance  avg_energy  avg_valence   avg_tempo
# 0    death-metal   0.368318    0.931468     0.247739  123.762797
# 1      grindcore   0.272077    0.924323     0.216354  119.268182
# 2      metalcore   0.423800    0.914485     0.314902  130.580195
# 3          happy   0.552697    0.910901     0.327686  152.920876
# 4      hardstyle   0.539411    0.901173     0.312074  146.905859
# ..           ...        ...         ...          ...         ...
# 109       disney   0.463030    0.302670     0.368759  112.045387
# 110      romance   0.431537    0.298848     0.394575  109.817137
# 111      ambient   0.367966    0.237257     0.167345  111.156413
# 112      new-age   0.348002    0.213872     0.182733  107.917950
# 113    classical   0.381959    0.195193     0.378502  108.047332
#
# [114 rows x 5 columns]
# /n
# Loudest tracks
#                                          track_name            primary_artist  loudness
# 0                                        Fate Dance           Five Star Hotel     4.532
# 1                                Islamic Capitalism                    Najand     3.156
# 2                                         Time Bomb             The Red Pears     2.574
# 3                        A Better World Is Possible                    Najand     1.864
# 4                TIPO HARIEL - SEI QUE E RARIDADE -            DJ BRUNO PRADO     1.821
# ...                                             ...                       ...       ...
# 89735       Chaconne in sol maggiore : Variazione 9              Lazar Berman   -43.957
# 89736       Cricket Sound 4 - Loopable With No Fade    White Noise for Babies   -46.251
# 89737                Ceiling Fan Sound on Low Power           Atmosphere Asmr   -46.591
# 89738           White Noise - Loopable With No Fade  White Noise Sleep Sounds   -49.307
# 89739  Soothing White Noise - Loopable With No Fade  White Noise Sleep Sounds   -49.531
#
# [89740 rows x 3 columns]
# /n
# 20 Longest tracks
#                                            track_name              primary_artist  duration_min  duration_sec
# 0                            Unity (Voyage Mix) Pt. 1                  Tale Of Us     87.288250      5237.295
# 1              Crossing Wires 002 - Continuous DJ Mix                   Timo Maas     79.817100      4789.026
# 2               The Lab 03 - Continuous DJ Mix Part 1                Seth Troxler     78.838367      4730.302
# 3                 Amnesia Ibiza Underground 10 DJ Mix                   Loco Dice     76.064950      4563.897
# 4          House of Om - Mark Farina - Continuous Mix                 Mark Farina     74.125333      4447.520
# 5                      Live In Tokyo - Continuous Mix                 Mark Farina     72.330433      4339.826
# 6                             Greenhouse Construction                 Mark Farina     72.245350      4334.721
# 7        NQ State of Mind, Vol. 1 - Continuous DJ Mix                     Lenzman     70.770100      4246.206
# 8                                  Ocean Waves Sounds                Ocean Sounds     68.670967      4120.258
# 9                        Internal Flight (Remastered)                 Estas Tonne     64.604600      3876.276
# 10                                    Internal Flight                 Estas Tonne     64.604600      3876.276
# 11  Kevin Saunderson History Elevate - Continuous Mix            Kevin Saunderson     61.279333      3676.760
# 12                 Ruido Rosa Puro - Una Hora Versión             El Ruido Blanco     60.028217      3601.693
# 13                         Vacuum Cleaner White Noise  Vacuum Cleaner White Noise     60.002000      3600.120
# 14                   Electric Fan (Sound Masking Fan)             Electric Dreams     60.000233      3600.014
# 15                                    Om Bhurbhuwasah            Anuradha Paudwal     55.677867      3340.672
# 16   Welcome To The Jungle - Continuous DJ Mix, Pt. 1                    Deekline     54.583317      3274.999
# 17                   Der ultimative Wendler Hitmix XL             Michael Wendler     49.322433      2959.346
# 18                                     Shiv Amritwani            Anuradha Paudwal     49.297333      2957.840
# 19                             Hits Of Immanuel Henry              Immanuel Henry     47.518483      2851.109
# /n
# 20 Shortest tracks
#                                                               track_name           primary_artist  duration_min  duration_sec
# 0                                                 The Exorsism Begins...               Leila Bela      0.143100         8.586
# 1                                                                    V-4               Leila Bela      0.223100        13.386
# 2                      Screams for a Finale! (feat. Leila's Opera Class)               Leila Bela      0.263333        15.800
# 3                                              Andante in C Major, K. 1a  Wolfgang Amadeus Mozart      0.290883        17.453
# 4                   Carnaval, Op. 9: No. 20, Pause (Live in Japan, 2022)          Robert Schumann      0.297100        17.826
# 5                                                                    V-7               Leila Bela      0.352000        21.120
# 6                                                                Shatter               Leila Bela      0.354000        21.240
# 7   Cello Suite No. 3, Op. 87: IX. Passacaglia (Excerpt: Autumn. Vivace)         Benjamin Britten      0.371100        22.266
# 8                Carnaval, Op. 9: No. 13, Estrella (Live in Japan, 2022)          Robert Schumann      0.391767        23.506
# 9                                                             Pax Domini              Traditional      0.400000        24.000
# 10                                                   Backpack, Backpack!        Dora The Explorer      0.404433        24.266
# 11                                                            Aural Blue       Alireza Mashayekhi      0.411100        24.666
# 12                                                                   V-3               Leila Bela      0.467100        28.026
# 13                                                         Breath Ritual               Leila Bela      0.482433        28.946
# 14                                                              Fanfarra              Alan Menken      0.501333        30.080
# 15                                               ABC (The Alphabet Song)        Dora The Explorer      0.503100        30.186
# 16                                                          Akkad Bakkad                  WowKidz      0.503483        30.209
# 17                                                             Rain Roof            Nature Sounds      0.503700        30.222
# 18                                                      Alone Once Again         Lack Of Interest      0.506550        30.393
# 19                            Tritonia (Tritonia 399) - Coming Up, Pt. 2                 Tritonal      0.507900        30.474
# /n
